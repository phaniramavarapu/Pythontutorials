# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Phani\\Desktop\\Phani - New\\Kaggle Data Sets\\nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.shape
# Out:
# (31, 11)

# %%
rows, columns = df.shape
print(rows)
print(columns)
# Out:
# 31
# 11

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.tail(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 29             257
# 30             241

# %%
df[2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df['DewPoint']
# Out:
# 0     23
# 1     18
# 2     21
# 3      9
# 4     -3
# 5      4
# 6     11
# 7     29
# 8     38
# 9     46
# 10     8
# 11    15
# 12     4
# 13    12
# 14    31
# 15    37
# 16    23
# 17     6
# 18     3
# 19    15
# 20    11
# 21     6
# 22    21
# 23    11
# 24    18
# 25    29
# 26    22
# 27    20
# 28    21
# 29    16
# 30    28
# Name: DewPoint, dtype: int64

# %%
type(df['WindSpeedMPH'])
# Out:
# pandas.core.series.Series

# %%
df[['Humidity', 'Sea Level PressureIn']]
# Out:
#     Humidity  Sea Level PressureIn
# 0         52                 30.03
# 1         46                 30.02
# 2         47                 29.86
# 3         44                 30.05
# 4         41                 30.57
# 5         35                 30.50
# 6         33                 30.28
# 7         64                 30.20
# 8         77                 30.16
# 9         71                 29.59
# 10        37                 29.92
# 11        53                 29.85
# 12        42                 29.94
# 13        47                 29.95
# 14        62                 29.82
# 15        70                 29.52
# 16        66                 29.78
# 17        53                 29.83
# 18        42                 30.03
# 19        49                 30.13
# 20        45                 30.15
# 21        41                 30.21
# 22        78                 29.77
# 23        53                 29.92
# 24        54                 30.25
# 25        56                 30.03
# ...

# %%
df['Humidity'].max()
# Out:
# 78

# %%
df['Humidity'].min()
# Out:
# 33

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df[df.Temperature>=40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2    1/3/2016           40        21        47                 29.86
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2                10           8.0               0           1    NaN
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# ...

# %%
df[df.Temperature==df['Temperature'].max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[['EST','Temperature']][df.Temperature==df['Temperature'].max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.set_index('EST')
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
df.set_index('EST', inplace =True)

# %%
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
df.loc['1/24/2016']
# Out:
# Temperature                28
# DewPoint                   11
# Humidity                   53
# Sea Level PressureIn    29.92
# VisibilityMiles             8
# WindSpeedMPH                6
# PrecipitationIn             T
# CloudCover                  3
# Events                   Snow
# WindDirDegrees            327
# Name: 1/24/2016, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.set_index('VisibilityMiles', inplace =True)

# %%
df
# Out:
#                        EST  Temperature  DewPoint  Humidity  \
# VisibilityMiles
# 10                1/1/2016           38        23        52
# 10                1/2/2016           36        18        46
# 10                1/3/2016           40        21        47
# 10                1/4/2016           25         9        44
# 10                1/5/2016           20        -3        41
# 10                1/6/2016           33         4        35
# 10                1/7/2016           39        11        33
# 10                1/8/2016           39        29        64
# 9                 1/9/2016           44        38        77
# 4                1/10/2016           50        46        71
# 10               1/11/2016           33         8        37
# 10               1/12/2016           35        15        53
# 10               1/13/2016           26         4        42
# 10               1/14/2016           30        12        47
# ...

# %%
df.loc[10]
# Out:
#                        EST  Temperature  DewPoint  Humidity  \
# VisibilityMiles
# 10                1/1/2016           38        23        52
# 10                1/2/2016           36        18        46
# 10                1/3/2016           40        21        47
# 10                1/4/2016           25         9        44
# 10                1/5/2016           20        -3        41
# 10                1/6/2016           33         4        35
# 10                1/7/2016           39        11        33
# 10                1/8/2016           39        29        64
# 10               1/11/2016           33         8        37
# 10               1/12/2016           35        15        53
# 10               1/13/2016           26         4        42
# 10               1/14/2016           30        12        47
# 10               1/19/2016           22         3        42
# 10               1/20/2016           32        15        49
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#     VisibilityMiles        EST  Temperature  DewPoint  Humidity  \
# 0                10   1/1/2016           38        23        52
# 1                10   1/2/2016           36        18        46
# 2                10   1/3/2016           40        21        47
# 3                10   1/4/2016           25         9        44
# 4                10   1/5/2016           20        -3        41
# 5                10   1/6/2016           33         4        35
# 6                10   1/7/2016           39        11        33
# 7                10   1/8/2016           39        29        64
# 8                 9   1/9/2016           44        38        77
# 9                 4  1/10/2016           50        46        71
# 10               10  1/11/2016           33         8        37
# 11               10  1/12/2016           35        15        53
# 12               10  1/13/2016           26         4        42
# 13               10  1/14/2016           30        12        47
# ...
